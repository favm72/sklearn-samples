# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from helper import plot_classifier

# %%
iris = load_iris()

# %%
X = iris.data[:, :2]
y = iris.target.reshape(-1, 1)
print(np.shape(X))
print(np.shape(y))
# Out:
# (150, 2)
# (150, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# f:\UDEMY\PYTHON\SCIKITLEARN\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
svc = SVC()
svc.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, svc.predict)

# %%
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, svc.predict)
# Out:
# f:\UDEMY\PYTHON\SCIKITLEARN\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svc = SVC(kernel='poly', degree=5)
svc.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, svc.predict)
# Out:
# f:\UDEMY\PYTHON\SCIKITLEARN\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svc = SVC(kernel='sigmoid')
svc.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, svc.predict)
# Out:
# f:\UDEMY\PYTHON\SCIKITLEARN\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
