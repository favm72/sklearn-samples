# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from helper import plot_classifier

# %%
iris = load_iris()

# %%
X = iris.data[:, :2]
y = iris.target.reshape(-1, 1)
print(np.shape(X))
print(np.shape(y))
# Out:
# (150, 2)
# (150, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
tree = DecisionTreeClassifier(max_depth=10, random_state=0)
tree.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, tree.predict)

# %%
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
plot_classifier.do_plot(X_train, y_train, forest.predict)
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_3216/1779632072.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train, y_train)
